# %% [markdown]
# # Explore seaborn
#
# Stefan/Yuzhao Heng
# Since Wed. Sep. 29th, 2021
#
# Explore in particular, the color palette choices.
#
#
# ## Setup

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from icecream import ic

from util import *

sns.set_style("dark")

# %% [markdown]
# ## Color palette
#
# ### Categorical ones

# %%
plot_all_palettes(n_colors=[8, 16, 32])
# Out:
# /Users/stefanh/Documents/UMich/Research/ECG-Classify/ECG-PVC-Classifier/venv/lib/python3.9/site-packages/seaborn/miscplot.py:21: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   f, ax = plt.subplots(1, 1, figsize=(n * size, size))
